# %% [markdown]
# # Try LDA without "side effect"-Term

# %% [markdown]
# ## Prepare dataset without "side effects"

# %%
import pandas as pd # DataFrame Manipulation Package
import numpy as np

# %%
data = pd.read_csv('../raw_data/drugsComTrain_raw.csv')
data.head()

train_data = data[100:5100].drop(["uniqueID", "condition", "rating", "date", "usefulCount"], axis =1)
print(train_data.shape)
train_data.head()
# Out:
# (5000, 2)
#                          drugName  \
# 100                      Macrobid
# 101                    Lurasidone
# 102  Adapalene / benzoyl peroxide
# 103                   Brimonidine
# 104       Amlodipine / olmesartan
#
#                                                 review
# 100  "Awful medicine, the worst. The side effects o...
# 101  "I&#039;ve been on Latuda for a little under 2...
# 102  "I&#039;ve seriously only been using Epiduo fo...
# 103  "This cream is absolutely horrible. I will adm...
# 104  "My blood pressure has been around 160/100. Do...

# %%
# data cleaning
import string 

def remove_punct(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    text = text.replace('\n', ' ')
    return text

def to_lower(text):
    return text.lower()

def remove_numbers(text):
    text = ''.join(word for word in text if not word.isdigit())
    return text

from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

def remove_stopwords(text):
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text) 
    text = [w for w in word_tokens if not w in stop_words]
    text = ' '.join(text)
    return text

from nltk.stem import WordNetLemmatizer

def lemmatize_text(text):
    lemmatizer = WordNetLemmatizer()
    lemmatized = [lemmatizer.lemmatize(word) for word in text]
    text = ''.join(lemmatized)
    return text

# %%
train_data["clean_review"] = train_data["review"].apply(remove_punct).apply(to_lower).apply(remove_numbers).apply(remove_stopwords).apply(lemmatize_text)

train_data.head()
# Out:
#                          drugName  \
# 100                      Macrobid
# 101                    Lurasidone
# 102  Adapalene / benzoyl peroxide
# 103                   Brimonidine
# 104       Amlodipine / olmesartan
#
#                                                 review  \
# 100  "Awful medicine, the worst. The side effects o...
# 101  "I&#039;ve been on Latuda for a little under 2...
# 102  "I&#039;ve seriously only been using Epiduo fo...
# 103  "This cream is absolutely horrible. I will adm...
# 104  "My blood pressure has been around 160/100. Do...
#
#                                           clean_review
# 100  awful medicine worst side effects outweigh ben...
# 101  ive latuda little half years almost completely...
# 102  ive seriously using epiduo four days seen huge...
# 103  cream absolutely horrible admit cream initiall...
# 104  blood pressure around doctor prescribed azor h...

# %%
# remove "side" and "effects"
train_data['clean_review'] = train_data['clean_review'].str.replace('side', '')
train_data['clean_review'] = train_data['clean_review'].str.replace('effects', '')
train_data
# Out:
#                           drugName  \
# 100                       Macrobid
# 101                     Lurasidone
# 102   Adapalene / benzoyl peroxide
# 103                    Brimonidine
# 104        Amlodipine / olmesartan
# ...                            ...
# 5095                   Oseltamivir
# 5096                      Losartan
# 5097                        Celexa
# 5098           Ortho Tri-Cyclen Lo
# 5099                        Qsymia
#
#                                                  review  \
# 100   "Awful medicine, the worst. The side effects o...
# 101   "I&#039;ve been on Latuda for a little under 2...
# 102   "I&#039;ve seriously only been using Epiduo fo...
# 103   "This cream is absolutely horrible. I will adm...
# 104   "My blood pressure has been around 160/100. Do...
# ...                                                 ...
# 5095  "Started feeling ill at lunchtime yesterday, b...
# 5096  "I was switched to Losartan from Lisinipril wh...
# 5097  "Was on Citalopram for 1 month then asked my d...
# 5098  "I&#039;ve been on Ortho Tri-Cyclen Lo for 4 y...
# 5099  "I took this back in 2012. I was 270 pounds wh...
#
#                                            clean_review
# 100   awful medicine worst   outweigh benefit headac...
# 101   ive latuda little half years almost completely...
# 102   ive seriously using epiduo four days seen huge...
# 103   cream absolutely horrible admit cream initiall...
# 104   blood pressure around doctor prescribed azor h...
# ...                                                 ...
# 5095  started feeling ill lunchtime yesterday time w...
# 5096  switched losartan lisinipril caused horrifying...
# 5097  citalopram month asked doctor change first wee...
# 5098  ive ortho tricyclen lo years first used contro...
# 5099  took back pounds started lost pounds months di...
#
# [5000 rows x 3 columns]

# %% [markdown]
# ## Simple LDA

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range = (2,2)).fit(train_data['clean_review'])
data_vectorized = vectorizer.transform(train_data['clean_review'])

lda_model = LatentDirichletAllocation(n_components=2).fit(data_vectorized)

# %%
# visualise output
def print_topics(model, vectorizer):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-10 - 1:-1]])
        
print_topics(lda_model, vectorizer)
# Out:
# Topic 0:
# [('side effects', 33.73979535993013), ('birth control', 17.22205603766533), ('works great', 11.560611558392786), ('side effect', 11.452744187490966), ('weight gain', 10.127115060511406), ('mood swings', 8.38747594833456), ('two weeks', 7.328212372035449), ('started taking', 7.243171083474), ('blood pressure', 6.898379075277094), ('stopped taking', 6.734157248412776)]
# Topic 1:
# [('side effects', 31.843987459515066), ('birth control', 15.544222900897253), ('started taking', 11.274575722450031), ('weight gain', 10.65655688228259), ('mood swings', 10.14500407010599), ('feel like', 9.548231608239165), ('sex drive', 8.566124048533354), ('side effect', 8.286765220007744), ('years ago', 8.01245077417522), ('years old', 7.718880835012835)]

# %% [markdown]
# ## Interpretation

# %%
# dummy test: is 'side effect' a topic?
example = ["side effect"]

example_vectorized = vectorizer.transform(example)
lda_vectors = lda_model.transform(example_vectorized)

print("topic 0 :", lda_vectors[0][0])
print("topic 1 :", lda_vectors[0][1]) 
# nope, makes sense, since it hasn't seen it before, it doesnt know where to put it.
# Out:
# topic 0 : 0.6497193900737439
# topic 1 : 0.3502806099262561

# %%
# compare to labelled data
test_data = pd.read_csv('../raw_data/manually_labelled_data.csv')
test_data = test_data.drop(["uniqueID", "condition", "rating", "date", "usefulCount"], axis =1)
test_data.head()
# Out:
#                    drugName  \
# 0                 Valsartan
# 1                Guanfacine
# 2                    Lybrel
# 3                Ortho Evra
# 4  Buprenorphine / naloxone
#
#                                               review  sideEffect
# 0  "It has no side effect, I take it in combinati...           0
# 1  "My son is halfway through his fourth week of ...           1
# 2  "I used to take another oral contraceptive, wh...           1
# 3  "This is my first time using any form of birth...           1
# 4  "Suboxone has completely turned my life around...           1

# %%
test_data["clean_review"] = test_data["review"].apply(remove_punct).apply(to_lower).apply(remove_numbers).apply(remove_stopwords).apply(lemmatize_text)

test_data.head()
# Out:
#                    drugName  \
# 0                 Valsartan
# 1                Guanfacine
# 2                    Lybrel
# 3                Ortho Evra
# 4  Buprenorphine / naloxone
#
#                                               review  sideEffect  \
# 0  "It has no side effect, I take it in combinati...           0
# 1  "My son is halfway through his fourth week of ...           1
# 2  "I used to take another oral contraceptive, wh...           1
# 3  "This is my first time using any form of birth...           1
# 4  "Suboxone has completely turned my life around...           1
#
#                                         clean_review
# 0  side effect take combination bystolic mg fish oil
# 1  son halfway fourth week intuniv became concern...
# 2  used take another oral contraceptive pill cycl...
# 3  first time using form birth control im glad we...
# 4  suboxone completely turned life around feel he...

# %%
# transform test_data
test_data_vectorized = vectorizer.transform(test_data['clean_review'])

lda_vectors = lda_model.transform(test_data_vectorized)

# %%
# Compare
predicted_topic = []
for row in range(len(test_data)):
    if (lda_vectors[row][0] > lda_vectors[row][1]):
        predicted_topic.append(0)
    else: predicted_topic.append(1)

(np.array(predicted_topic) == np.array(test_data.sideEffect)).sum()

## 55% --> pretty much randomly assigned
# Out:
# 59

# %% [markdown]
# # MNBayes

# %%
data = pd.read_csv('../raw_data/drugsComTrain_raw.csv')
data.head()

train_data = data[100:5100].drop(["uniqueID", "condition", "rating", "date", "usefulCount"], axis =1)
print(train_data.shape)
train_data.head()
# Out:
# (5000, 2)
#                          drugName  \
# 100                      Macrobid
# 101                    Lurasidone
# 102  Adapalene / benzoyl peroxide
# 103                   Brimonidine
# 104       Amlodipine / olmesartan
#
#                                                 review
# 100  "Awful medicine, the worst. The side effects o...
# 101  "I&#039;ve been on Latuda for a little under 2...
# 102  "I&#039;ve seriously only been using Epiduo fo...
# 103  "This cream is absolutely horrible. I will adm...
# 104  "My blood pressure has been around 160/100. Do...

# %%
train_data["clean_review"] = train_data["review"].apply(remove_punct).apply(to_lower).apply(remove_numbers).apply(remove_stopwords).apply(lemmatize_text)

train_data.head()
# Out:
#                          drugName  \
# 100                      Macrobid
# 101                    Lurasidone
# 102  Adapalene / benzoyl peroxide
# 103                   Brimonidine
# 104       Amlodipine / olmesartan
#
#                                                 review  \
# 100  "Awful medicine, the worst. The side effects o...
# 101  "I&#039;ve been on Latuda for a little under 2...
# 102  "I&#039;ve seriously only been using Epiduo fo...
# 103  "This cream is absolutely horrible. I will adm...
# 104  "My blood pressure has been around 160/100. Do...
#
#                                           clean_review
# 100  awful medicine worst side effects outweigh ben...
# 101  ive latuda little half years almost completely...
# 102  ive seriously using epiduo four days seen huge...
# 103  cream absolutely horrible admit cream initiall...
# 104  blood pressure around doctor prescribed azor h...

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split


vectorizer_mnb = TfidfVectorizer()

X = vectorizer_mnb.fit_transform(test_data.clean_review)
y = test_data.sideEffect

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 4)

nb_model = MultinomialNB()
nb_model.fit(X_train,y_train)
nb_model.score(X_test,y_test)
# Out:
# 0.6333333333333333

# %%
# as crossvalidation
from sklearn.model_selection import cross_validate

X = test_data.clean_review
y = test_data.sideEffect
nb_model = MultinomialNB()

cv_results = cross_validate(nb_model, X, y, cv=5)

cv_results['test_score'].mean()
# Out:
# /Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 615, in fit
#     X, y = self._check_X_y(X, y)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 480, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/series.py", line 797, in __array__
#     return np.asarray(self.array, dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py", line 211, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'started nexplanon months ago minimal amount contraceptions take due inability take hormone used birth controls im trying give time one options right honestly options id get removed ive never acne problems life immediately broke getting implanted sex drive completely gone used sex boyfriend days week completely forced even fun anymore mean im birth control like sex dont want get pregnant take birth control takes away sex unhappy hope get back time im getting removed'
#
#   FitFailedWarning)
# /Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 615, in fit
#     X, y = self._check_X_y(X, y)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 480, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/series.py", line 797, in __array__
#     return np.asarray(self.array, dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py", line 211, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'side effect take combination bystolic mg fish oil'
#
#   FitFailedWarning)
# /Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 615, in fit
#     X, y = self._check_X_y(X, y)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 480, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/series.py", line 797, in __array__
#     return np.asarray(self.array, dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py", line 211, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'side effect take combination bystolic mg fish oil'
#
#   FitFailedWarning)
# /Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 615, in fit
#     X, y = self._check_X_y(X, y)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 480, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/series.py", line 797, in __array__
#     return np.asarray(self.array, dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py", line 211, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'side effect take combination bystolic mg fish oil'
#
#   FitFailedWarning)
# /Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 615, in fit
#     X, y = self._check_X_y(X, y)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/naive_bayes.py", line 480, in _check_X_y
#     return self._validate_data(X, y, accept_sparse='csr')
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/base.py", line 432, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 802, in check_X_y
#     estimator=estimator)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 72, in inner_f
#     return f(**kwargs)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/sklearn/utils/validation.py", line 598, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/series.py", line 797, in __array__
#     return np.asarray(self.array, dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/pandas/core/arrays/numpy_.py", line 211, in __array__
#     return np.asarray(self._ndarray, dtype=dtype)
#   File "/Users/hendrike.dahmke/.pyenv/versions/3.7.7/envs/lewagon/lib/python3.7/site-packages/numpy/core/_asarray.py", line 85, in asarray
#     return array(a, dtype, copy=False, order=order)
# ValueError: could not convert string to float: 'side effect take combination bystolic mg fish oil'
#
#   FitFailedWarning)
# nan
